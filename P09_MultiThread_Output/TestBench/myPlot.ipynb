# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv("P09_MT_1GeV_electron.csv", comment = '#', header=None)
#data.head()

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(2,2,1)


ax1.grid(True)
ax1.set_xlabel("E deposit(MeV)")
ax1.set_ylabel("Step length (mm)")
ax1.set_title("proton into BGO")
#ax1.set_ylim(8000, 12000.)
#ax1.set_xlim(800, 1000)
ax1.scatter(data[0], data[1], s=1, marker= '.')

ax2 = fig.add_subplot(2,2,2)
ax2.set_ylabel("Step length (mm)")
ax2.set_xscale('log')
ax2.hist(data[1], bins=100,orientation='horizontal')  #, range=[8000., 12000.])

ax3 = fig.add_subplot(2,2,3)
ax3.set_yscale('log')
ax3.set_xlabel("Energy Deposit (MeV)")
ax3.hist(data[0], bins=100) #, range=[800,  1000])
# Out:
# (array([4.000e+00, 6.000e+00, 1.300e+01, 1.800e+01, 2.500e+01, 2.400e+01,
#         3.200e+01, 4.500e+01, 4.200e+01, 6.900e+01, 8.200e+01, 8.000e+01,
#         1.100e+02, 1.060e+02, 1.380e+02, 1.500e+02, 1.640e+02, 2.090e+02,
#         2.210e+02, 2.430e+02, 3.110e+02, 3.110e+02, 3.540e+02, 4.520e+02,
#         4.690e+02, 5.350e+02, 6.010e+02, 6.490e+02, 6.810e+02, 7.660e+02,
#         8.720e+02, 9.250e+02, 9.800e+02, 1.115e+03, 1.122e+03, 1.196e+03,
#         1.328e+03, 1.411e+03, 1.469e+03, 1.544e+03, 1.640e+03, 1.752e+03,
#         1.723e+03, 1.803e+03, 1.851e+03, 1.931e+03, 1.992e+03, 2.064e+03,
#         2.043e+03, 2.102e+03, 2.065e+03, 2.155e+03, 2.129e+03, 2.150e+03,
#         2.151e+03, 2.100e+03, 2.094e+03, 1.963e+03, 1.973e+03, 1.927e+03,
#         1.852e+03, 1.749e+03, 1.627e+03, 1.653e+03, 1.520e+03, 1.446e+03,
#         1.340e+03, 1.231e+03, 1.164e+03, 1.131e+03, 9.480e+02, 8.310e+02,
#         7.670e+02, 6.620e+02, 5.890e+02, 5.240e+02, 4.220e+02, 3.980e+02,
# ...
